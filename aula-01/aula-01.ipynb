# %% [markdown]
# # Aula 01 - O que é Programação e Seu Primeiro Código

# %% [markdown]
# ## O que é um algoritmo?

# %% [markdown]
# *“Algoritmo é uma sequência de passos que visa atingir um objetivo bem definido”*
# (FORBELLONE, 2005, p. 3).

# %% [markdown]
# <u>**ALGORITMO PARA FAZER UM SANDUÍCHE**<u>
#
# Passo 1 – PEGAR O PÃO E A FACA.
#
# Passo 2 – CORTAR O PÃO AO MEIO.
#
# Passo 3 – PEGAR A MAIONESE.
#
# Passo 4 – PASSAR A MAIONESE, COM O AUXÍLIO DA FACA, NO PÃO.
#
# Passo 5 – PEGAR E CORTAR ALFACE E TOMATE.
#
# Passo 6 – COLOCAR ALFACE E TOMATE NO PÃO.
#
# Passo 7 – PEGAR O HAMBÚRGUER.
#
# Passo 8 – FRITAR O HAMBÚRGUER.
#
# Passo 9 – COLOCAR O HAMBÚRGUER NO PÃO.

# %% [markdown]
# ***O primeiro algoritmo, escrito por Ada Lovelace***
#
# <img src="./assets/primeiro_algoritmo.png" alt="O primeiro algoritmo. Escrito por Ada Lovelace" width="1200">

# %% [markdown]
# ## Por que Python?

# %% [markdown]
# - Python é uma das melhores linguagens de programação para iniciantes.
#
# - Ela foi criada em 1989 e o seu nome é uma homenagem à série *Monty Python.*
#
# - Se parece muito com o inglês escrito.
#
# - É a base das inteligências artificiais mais comuns (GPTs, por exemplo).
#
# - É usada por muitos profissionais onde a atividade profissional principal não é a programação

# %% [markdown]
# ## Jupyter Notebook e o Google Colab

# %% [markdown]
# O Jupyter Notebook é uma aplicação web de código aberto que permite criar e compartilhar documentos interativos combinando código executável, textos explicativos, fórmulas e gráficos em um só lugar.
#
# O nome “Jupyter” deriva das principais linguagens de programação suportadas: Julia, Python e R.
#
# O Google Colaboratory, ou Google Colab, é uma plataforma gratuita que fornece um ambiente de Jupyter Notebook hospedado na nuvem que permite escrever e executar código Python.
#
# **O único requisito é ter uma conta Google**

# %% [markdown]
# ## A função print( )

# %% [markdown]
# Print é a função em Python que usamos para exibir algo na tela.
#
# Sua estrutura básica é: print(*"O que queremos exibir"*).

# %%
print (Olá Mundo!)
# Out:
#   Cell In[5], line 1
#     print (Olá Mundo!)
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print ("Olá Mundo!")
# Out:
# Olá Mundo!

# %% [markdown]
# Nós também podemos usar vários prints em sequência:

# %%
print("Iniciando o curso de Python...")
print("Esta é a minha primeira instrução.")
print("Programar é mais fácil do que parece!")
# Out:
# Iniciando o curso de Python...
# Esta é a minha primeira instrução.
# Programar é mais fácil do que parece!

# %% [markdown]
# ## Exercícios Práticos

# %% [markdown]
# ### Exercício 1

# %% [markdown]
# Escreva um programa que exiba exatamente a frase: Olá, Mundo! Eu sou o mais novo programador.

# %%
print("Olá, Mundo! Eu sou o mais novo programador.")
# Out:
# Olá, Mundo! Eu sou o mais novo programador.

# %% [markdown]
# ### Exercício 2

# %% [markdown]
# Crie um script que mostre 3 linhas na tela: seu nome na primeira, sua cidade na segunda e seu hobby favorito na terceira.

# %%
print("Meu nome é Mari.")
print("Moro em São Paulo.")
print("Gosto de estudar Inteligência Artificial e programar.")
# Out:
# Meu nome é Mari.
# Moro em São Paulo.
# Gosto de estudar Inteligência Artificial e programar.

# %% [markdown]
# ### Exercício 3: Cartão de Visitas Digital (Desafio Criativo)

# %% [markdown]
# Use o comando print() para desenhar uma moldura simples ao redor de uma mensagem, usando caracteres como * ou -.

# %% [markdown]
# Formato de resposta esperado:
#
# ```python
#   ***********************
#   *  BEM-VINDO AO CURSO *
#   *   PYTHON DO ZERO    *
#   ***********************

# %%
print("***********************")
print("*  BEM-VINDO AO CURSO *")
print("*   PYTHON DO ZERO    *")
print("***********************")
