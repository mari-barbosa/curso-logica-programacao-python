# %% [markdown]
# # Aula 01 - O que é Programação e Seu Primeiro Código

# %% [markdown]
# ## O que é um algoritmo?

# %% [markdown]
# ## Por que Python?

# %% [markdown]
# ## O Google Colab

# %% [markdown]
# ## A função (print)
