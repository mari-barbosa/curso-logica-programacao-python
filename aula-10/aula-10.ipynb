# %% [markdown]
# # Aula 10: Projeto Final

# %% [markdown]
# Nós iremos criar juntos um sistema de gerenciamento de tarefas com opcões de adicionar, listar e remover as nossas tarefas.
#
# Não utilizaremos interface gráfica. Tudo rodará direto na tela do Google Colab e, caso você baixe o arquivo final para o seu pc, via terminal.

# %% [markdown]
# <u>**Requisitos do Projeto:**<u>
#
# - [ ] Exibir um menu com opções ativas (Adicionar, Listar, Remover, Sair).
#
# - [ ] Manter o programa rodando até o usuário decidir fechar.
#
# - [ ] Guardar as tarefas em uma lista.
#
# - [ ] Organizar as ações em funções separadas.

# %% [markdown]
# ## 1. A Estrutura do Menu Interativo com Loop

# %% [markdown]
# ## 2.Criando as Funções Auxiliares

# %% [markdown]
# ### 2.1 Função adicionar_tarefas( )

# %% [markdown]
# ### 2.2 Função listar_tarefas( )

# %% [markdown]
# ### 2.3 Função remover_tarefas( )

# %% [markdown]
# ## 3. Criando o menu com as opções

# %% [markdown]
# ## 4. Juntando Tudo

# %% [markdown]
# ## Desafios Extras de Conclusão

# %% [markdown]
# - Marcar como Concluída: Modifique a função de listar para aceitar uma marcação de [X] nas tarefas finalizadas.
#
# - Contador de Tarefas: Exiba no topo do menu quantas tarefas estão pendentes.
